# %% [markdown]
# # Read from CSV and Write into Bronze table

# %% [markdown]
# # load ''cust_info.csv''

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_crm/cust_info.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.crm_cust_info")

# %% [markdown]
# # load "prd_info.csv"

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_crm/prd_info.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.crm_prd_info")

# %% [markdown]
# # load "sales_details.csv"

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_crm/sales_details.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.crm_sales_details")

# %% [markdown]
# # load "CUST_AZ12.csv"

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_erp/CUST_AZ12.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.erp_CUST_AZ12")

# %% [markdown]
# # load "LOC_A101.csv"

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_erp/LOC_A101.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.erp_LOC_A101")

# %% [markdown]
# # load "PX_CAT_G1V2.csv"

# %%
df = spark.read.option("header","true").option("inferSchema","true").csv('/Volumes/bikescatalog/bronze/raw_sources/engineering/source_erp/PX_CAT_G1V2.csv')
df.write.mode("overwrite").saveAsTable("bikescatalog.bronze.erp_PX_CAT_G1V2")
